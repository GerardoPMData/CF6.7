# %% [markdown]
# # Excercise 6.2  - Gerardo Pérez

# %%
# Importing Libraries:

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.9.2'

# %%
# %matplotlib inline

# %%
# Define Path

path = r'C:\Users\geram\OneDrive\Escritorio\Data Analysis\Coral Bleaching'

# %%
path
# Out:
# 'C:\\Users\\geram\\OneDrive\\Escritorio\\Data Analysis\\Coral Bleaching'

# %%
coral_bleach = pd.read_csv(r'C:\Users\geram\OneDrive\Escritorio\Data Analysis\Coral Bleaching\Coral Bleaching Project updated - Gerardo Pérez.csv', delimiter=';', index_col=False)

# %%
coral_bleach.head()
# Out:
#    Sample_ID Cyclone_Frequency Depth_m Ocean_Name      Country_Name  \
# 0   10324336              49,9      10   Atlantic              Cuba
# 1   10324754              51,2      14    Pacific  French Polynesia
# 2   10323866             61,52       7   Atlantic    United Kingdom
# 3   10328028             65,39    9,02   Atlantic     United States
# 4   10328029             65,39    12,5   Atlantic     United States
#
#   Distance_to_Shore Exposure Turbidity  Date_Year Bleaching_Level  ...  \
# 0           8519,23  Exposed    0,0287       2005          Colony  ...
# 1           1431,62  Exposed    0,0262       1991          Colony  ...
# 2            182,33  Exposed    0,0429       2006          Colony  ...
# 3            313,13  Exposed    0,0424       2006          Colony  ...
# 4               792  Exposed    0,0424       2006          Colony  ...
#
#   Unnamed: 16             Unnamed: 17        Unnamed: 18  Unnamed: 19  \
# ...

# %%
coral_bleach.drop(columns=['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], inplace=True)

# %%
coral_bleach_2010_2019 = coral_bleach[coral_bleach['Date_Year'].between(2010, 2019)]

# %%
coral_bleach_2010_2019.head()
# Out:
#      Sample_ID Cyclone_Frequency Depth_m Ocean_Name      Country_Name  \
# 110   10314534             52,33       2    Pacific  French Polynesia
# 150   10314534             52,33       2    Pacific  French Polynesia
# 175   10321370             50,27       5    Pacific          Thailand
# 269   10321370             50,27       5    Pacific          Thailand
# 354   10290574             35,71      14     Indian        Madagascar
#
#     Distance_to_Shore   Exposure Turbidity  Date_Year Bleaching_Level  \
# 110            357,92  Sheltered      0,03       2019      Population
# 150            357,92  Sheltered      0,03       2019      Population
# 175             73,88    Exposed      0,06       2014      Population
# 269             73,88    Exposed      0,06       2014      Population
# 354           8768,03  Sometimes      0,06       2016          Colony
#
#     Temperature_Maximum Percent_Bleaching Temperature_Mean  \
# 110              304,77               100           300,89
# ...

# %%
coral_bleach_2010_2019.drop(columns=['Unnamed: 15'], inplace=True)
# Out:
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\2215155236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coral_bleach_2010_2019.drop(columns=['Unnamed: 15'], inplace=True)

# %%
coral_bleach_2010_2019.head()
# Out:
#      Sample_ID Cyclone_Frequency Depth_m Ocean_Name      Country_Name  \
# 110   10314534             52,33       2    Pacific  French Polynesia
# 150   10314534             52,33       2    Pacific  French Polynesia
# 175   10321370             50,27       5    Pacific          Thailand
# 269   10321370             50,27       5    Pacific          Thailand
# 354   10290574             35,71      14     Indian        Madagascar
#
#     Distance_to_Shore   Exposure Turbidity  Date_Year Bleaching_Level  \
# 110            357,92  Sheltered      0,03       2019      Population
# 150            357,92  Sheltered      0,03       2019      Population
# 175             73,88    Exposed      0,06       2014      Population
# 269             73,88    Exposed      0,06       2014      Population
# 354           8768,03  Sometimes      0,06       2016          Colony
#
#     Temperature_Maximum Percent_Bleaching Temperature_Mean  \
# 110              304,77               100           300,89
# ...

# %%
# Dataframe contains now only the variables of interest, delimited from 2010 to 2019

# %%
coral_bleach_2010_2019.shape
# Out:
# (14604, 15)

# %%
coral_bleach_2010_2019.columns
# Out:
# Index(['Sample_ID', 'Cyclone_Frequency', 'Depth_m', 'Ocean_Name',
#        'Country_Name', 'Distance_to_Shore', 'Exposure', 'Turbidity',
#        'Date_Year', 'Bleaching_Level', 'Temperature_Maximum',
#        'Percent_Bleaching', 'Temperature_Mean', 'Realm_Name', 'Percent_Cover'],
#       dtype='object')

# %%
coral_bleach_2010_2019.dtypes
# Out:
# Sample_ID               int64
# Cyclone_Frequency      object
# Depth_m                object
# Ocean_Name             object
# Country_Name           object
# Distance_to_Shore      object
# Exposure               object
# Turbidity              object
# Date_Year               int64
# Bleaching_Level        object
# Temperature_Maximum    object
# Percent_Bleaching      object
# Temperature_Mean       object
# Realm_Name             object
# Percent_Cover          object
# dtype: object

# %%
# Check for missing values

coral_bleach_2010_2019.isnull().sum()
# Out:
# Sample_ID                 0
# Cyclone_Frequency         0
# Depth_m                   0
# Ocean_Name                0
# Country_Name              0
# Distance_to_Shore         0
# Exposure                  0
# Turbidity                 0
# Date_Year                 0
# Bleaching_Level           0
# Temperature_Maximum       0
# Percent_Bleaching         0
# Temperature_Mean          0
# Realm_Name                0
# Percent_Cover          2049
# dtype: int64

# %%
coral_bleach_2010_2019.drop(columns=['Percent_Cover'], inplace=True)
# Out:
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\1063341949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coral_bleach_2010_2019.drop(columns=['Percent_Cover'], inplace=True)

# %%
coral_bleach_2010_2019.isnull().sum()
# Out:
# Sample_ID              0
# Cyclone_Frequency      0
# Depth_m                0
# Ocean_Name             0
# Country_Name           0
# Distance_to_Shore      0
# Exposure               0
# Turbidity              0
# Date_Year              0
# Bleaching_Level        0
# Temperature_Maximum    0
# Percent_Bleaching      0
# Temperature_Mean       0
# Realm_Name             0
# dtype: int64

# %%
# No missing values found, variable "Percent_Cover" has been dropped from the dataframe, as the original data source does not contain any information (thus, the missing values in the code above)

# %%
# Checking for duplicates:

coral_bleach_2010_2019_dups = coral_bleach_2010_2019[coral_bleach_2010_2019.duplicated()]

# %%
coral_bleach_2010_2019_dups.shape
# Out:
# (6175, 14)

# %%
# Display duplicate rows
duplicates = coral_bleach_2010_2019[coral_bleach_2010_2019.duplicated()]
print(duplicates)
# Out:
#        Sample_ID Cyclone_Frequency Depth_m Ocean_Name      Country_Name  \
# 150     10314534             52,33       2    Pacific  French Polynesia
# 269     10321370             50,27       5    Pacific          Thailand
# 568     10321359             50,27     4,5    Pacific          Thailand
# 711     10313820                36       3    Pacific         Australia
# 981     10310411             47,39       4    Pacific         Indonesia
# ...          ...               ...     ...        ...               ...
# 32649   10321650             47,93       5    Red Sea             Egypt
# 32719   10317342             47,58     5,9    Red Sea             Egypt
# 32721   10319611             42,42       6     Indian          Maldives
# 32725   10322065             54,44     6,9    Pacific          Malaysia
# 32727   10310781             54,44     5,8    Pacific          Malaysia
#
#       Distance_to_Shore   Exposure Turbidity  Date_Year Bleaching_Level  \
# ...

# %%
# While the duplicates check reveals 6715 duplicates in 14 columnns, a revision of the data shows that the duplicates are actual correct

# %%
# Mixed type data check:

for col in coral_bleach_2010_2019.columns.tolist():
      weird = (coral_bleach_2010_2019[[col]].applymap(type) != coral_bleach_2010_2019[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (coral_bleach_2010_2019[weird]) > 0:
        print (col)
# Out:
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\554862938.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (coral_bleach_2010_2019[[col]].applymap(type) != coral_bleach_2010_2019[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\554862938.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (coral_bleach_2010_2019[[col]].applymap(type) != coral_bleach_2010_2019[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\554862938.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (coral_bleach_2010_2019[[col]].applymap(type) != coral_bleach_2010_2019[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\554862938.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
for col in coral_bleach_2010_2019.columns.tolist():
    weird = (coral_bleach_2010_2019[col].map(type) != type(coral_bleach_2010_2019[col].iloc[0]))
    if weird.any():
        print(col)
# Out:
# Sample_ID
# Date_Year

# %%
# There is mixed data types in variables Sample_ID and Date_Year

# %%
print(coral_bleach_2010_2019['Sample_ID'].apply(type).value_counts())
print(coral_bleach_2010_2019['Date_Year'].apply(type).value_counts())
# Out:
# Sample_ID
# <class 'int'>    14604
# Name: count, dtype: int64
# Date_Year
# <class 'int'>    14604
# Name: count, dtype: int64

# %%
# Checking the variables in question revelas there is actually no mixed data types

# %%
# Exploring  Relationships - Correlations

# %%
coral_bleach_2010_2019.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 coral_bleach_2010_2019.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
# The dataframe seems to contain non-numeric data

# %%
# Solution: identify non-numeric columns

# %%
non_numeric_columns = coral_bleach_2010_2019.select_dtypes(exclude=['number']).columns
print(non_numeric_columns)
# Out:
# Index(['Cyclone_Frequency', 'Depth_m', 'Ocean_Name', 'Country_Name',
#        'Distance_to_Shore', 'Exposure', 'Turbidity', 'Bleaching_Level',
#        'Temperature_Maximum', 'Percent_Bleaching', 'Temperature_Mean',
#        'Realm_Name'],
#       dtype='object')

# %%
# Check data types

# %%
print(coral_bleach_2010_2019[non_numeric_columns].dtypes)
# Out:
# Cyclone_Frequency      object
# Depth_m                object
# Ocean_Name             object
# Country_Name           object
# Distance_to_Shore      object
# Exposure               object
# Turbidity              object
# Bleaching_Level        object
# Temperature_Maximum    object
# Percent_Bleaching      object
# Temperature_Mean       object
# Realm_Name             object
# dtype: object

# %%
# Covert data to numeric values

# %%
coral_bleach_2010_2019.loc[:, 'Cyclone_Frequency'] = pd.to_numeric(coral_bleach_2010_2019['Cyclone_Frequency'], errors='coerce')
coral_bleach_2010_2019.loc[:, 'Depth_m'] = pd.to_numeric(coral_bleach_2010_2019['Depth_m'], errors='coerce')
coral_bleach_2010_2019.loc[:, 'Distance_to_Shore'] = pd.to_numeric(coral_bleach_2010_2019['Distance_to_Shore'], errors='coerce')
coral_bleach_2010_2019.loc[:, 'Turbidity'] = pd.to_numeric(coral_bleach_2010_2019['Turbidity'], errors='coerce')
coral_bleach_2010_2019.loc[:, 'Temperature_Maximum'] = pd.to_numeric(coral_bleach_2010_2019['Temperature_Maximum'], errors='coerce')
coral_bleach_2010_2019.loc[:, 'Percent_Bleaching'] = pd.to_numeric(coral_bleach_2010_2019['Percent_Bleaching'], errors='coerce')
coral_bleach_2010_2019.loc[:, 'Temperature_Mean'] = pd.to_numeric(coral_bleach_2010_2019['Temperature_Mean'], errors='coerce')

# %%
# Checking for correlations

# %%
# Selecting only numeric columns using .loc
numeric_columns = coral_bleach_2010_2019.loc[:, coral_bleach_2010_2019.columns.isin([
    'Cyclone_Frequency', 'Depth_m', 'Distance_to_Shore', 'Turbidity', 
    'Temperature_Maximum', 'Percent_Bleaching', 'Temperature_Mean'])]

# %%
# Calculating the correlation matrix
correlation_coral_bleach = numeric_columns.corr()

# %%
print(correlation_coral_bleach)
# Out:
#                      Cyclone_Frequency   Depth_m  Distance_to_Shore  \
# Cyclone_Frequency             1.000000  0.067471                NaN
# Depth_m                       0.067471  1.000000           0.064008
# Distance_to_Shore                  NaN  0.064008           1.000000
# Turbidity                          NaN       NaN                NaN
# Temperature_Maximum                NaN  0.253634          -0.024727
# Percent_Bleaching            -0.058855 -0.071072           0.133362
# Temperature_Mean                   NaN  0.161401                NaN
#
#                      Turbidity  Temperature_Maximum  Percent_Bleaching  \
# Cyclone_Frequency          NaN                  NaN          -0.058855
# Depth_m                    NaN             0.253634          -0.071072
# Distance_to_Shore          NaN            -0.024727           0.133362
# Turbidity                  NaN                  NaN                NaN
# ...

# %% [markdown]
# # 3. Create a correlation matrix heatmap (colored)

# %%
# Select only the numeric columns for correlation
numerical_cols = ['Cyclone_Frequency', 'Depth_m', 'Distance_to_Shore', 
                  'Turbidity', 'Temperature_Maximum', 'Percent_Bleaching', 'Temperature_Mean']

# %%
# Create a correlation matrix
corr_matrix = coral_bleach_2010_2019[numerical_cols].corr()

# %%
# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)

plt.show()

# %%
coral_bleach_2010_2019[['Turbidity', 'Distance_to_Shore']].describe()
# Out:
#        Turbidity  Distance_to_Shore
# count        0.0        1595.000000
# mean         NaN        4733.507837
# std          NaN        3136.660807
# min          NaN          12.000000
# 25%          NaN        1618.000000
# 50%          NaN        5010.000000
# 75%          NaN        7308.000000
# max          NaN       13394.000000

# %%
# Converting the 'Turbidity' variable into numeric data type

# %%
coral_bleach_2010_2019.loc[:, 'Turbidity'] = coral_bleach_2010_2019['Turbidity'].replace(',', '.', regex=True).astype(float)

# %%
coral_bleach_2010_2019[['Turbidity', 'Distance_to_Shore']].describe()
# Out:
#        Turbidity  Distance_to_Shore
# count        0.0        1595.000000
# mean         NaN        4733.507837
# std          NaN        3136.660807
# min          NaN          12.000000
# 25%          NaN        1618.000000
# 50%          NaN        5010.000000
# 75%          NaN        7308.000000
# max          NaN       13394.000000

# %%
coral_bleach_2010_2019['Turbidity'][~coral_bleach_2010_2019['Turbidity'].apply(pd.to_numeric, errors='coerce').notna()]
# Out:
# 110     NaN
# 150     NaN
# 175     NaN
# 269     NaN
# 354     NaN
#          ..
# 32721   NaN
# 32722   NaN
# 32725   NaN
# 32726   NaN
# 32727   NaN
# Name: Turbidity, Length: 14604, dtype: float64

# %%
coral_bleach_2010_2019['Turbidity'] = pd.to_numeric(coral_bleach_2010_2019['Turbidity'], errors='coerce')
# Out:
# C:\Users\geram\AppData\Local\Temp\ipykernel_13852\742074669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coral_bleach_2010_2019['Turbidity'] = pd.to_numeric(coral_bleach_2010_2019['Turbidity'], errors='coerce')

# %%
coral_bleach_2010_2019.loc[:, 'Turbidity'] = pd.to_numeric(coral_bleach_2010_2019['Turbidity'], errors='coerce')

# %%
print(coral_bleach_2010_2019['Turbidity'].dtype)
# Out:
# float64

# %%
coral_bleach_2010_2019['Turbidity'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Turbidity, dtype: float64

# %% [markdown]
# # Question for Bashir -> i have tried changing the data type for a numeric type in order to make the heatmap work, but Turbidity continues to appear NaN values which does not make sense

# %% [markdown]
# # 3.1 Results of the correlation matrix:

# %%
# Strong positive correlation (values close to 1) indicates that as one variable increases, the other tends to increase as well. For example, "Temperature_Maximum" and "Percent_Bleaching" have a correlation of 0.39, suggesting a moderate positive relationship.
# Negative correlations (values closer to -1) indicate that as one variable increases, the other tends to decrease. For example, "Cyclone_Frequency" and "Percent_Bleaching" have a slight negative correlation of -0.06.
# Low or no correlation (values close to 0) indicates no significant relationship between variables, like "Turbidity", however, the dataframe seems to be inconsistant, as Turbidity contains indeed numeric values but theyre not tecognized as such, and thus, no correlation can be calculated

# %% [markdown]
# # 4. Scatterplot

# %%
sns.lmplot(x = 'Cyclone_Frequency', y = 'Percent_Bleaching', data = coral_bleach_2010_2019)

# %%
sns.lmplot(x='Cyclone_Frequency', y='Percent_Bleaching', data=coral_bleach_2010_2019)
plt.show()

# %%
sns.lmplot(x='Temperature_Maximum', y='Percent_Bleaching', data=coral_bleach_2010_2019)
plt.show()

# %%
sns.lmplot(x='Depth_m', y='Percent_Bleaching', data=coral_bleach_2010_2019)
plt.show()

# %%
# Scatterplot results:

# Cyclone_frequency and Percent_Bleaching dont show a strong relationship, with a trend line decreasing and several outliers 
# Temperature_Maximum and percent_bleaching show an interesting, positive correlation, indicating that more bleaching is expected to appear the hotter the temperatures get
# Another interesting relationship exlpored was Depth vs bleaching, where the negative correlation result indicates that the deeper the water is, the less likely it will be to encounter coral bleaching

# %% [markdown]
# # 5. Create a pair plot

# %%
Coral_Bleach_2 = coral_bleach_2010_2019[['Cyclone_Frequency', 'Depth_m', 'Distance_to_Shore', 
                  'Turbidity', 'Temperature_Maximum', 'Percent_Bleaching', 'Temperature_Mean']]

# %%
g = sns.pairplot(Coral_Bleach_2)

# %%
plt.show()

# %%
# The variables showing interesting relationships would be the ones related to percent_bleaching
# Depth_m, distance to shore and temperature would be the optimal ones to start revising further data insights

# %% [markdown]
# # 6. Create Categorical Plots

# %%
# Histogram of 'Ocean_Name'

sns.histplot(coral_bleach_2010_2019['Ocean_Name'], discrete=True, bins=5)
plt.title('Distribution of Oceans')
plt.show()

# %%
# The majority of data from this data frame comes has been reported in the Pacific ocean, followed by the Atlantic ocean

# %% [markdown]
# # 7. Revisiting Hypotheses

# %%
# Some variables and hyppotheses proposed before, such as higher water temperatures inducing coral bleaching, as well as depth having a relationship which can be tested and proved.
# Further relationships, perhaps more specifically targeting categorical, instead of numerical variables, would most likely deliver further insight on the coral bleaching disease

# %%
coral_bleach_2010_2019.to_csv(r'C:\Users\geram\OneDrive\Escritorio\Data Analysis\Coral Bleaching\updated_coral_bleach_2010_2019.csv', index=False)
